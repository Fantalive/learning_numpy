# %% [markdown]
# # Creating numpy arrays
#
# Normal array:

# %%
list_1 = [ 1, 2, 3 ]
print( list_1 )
# Out:
# [1, 2, 3]

# %% [markdown]
# # Creating Numpy Array

# %%
import numpy as np

# %%
numpy_1 = np.array( list_1 )
print( numpy_1 )
# Out:
# [1 2 3]
